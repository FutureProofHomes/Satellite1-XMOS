# %%
from pathlib import Path
import sys
import os
PRJ_ROOT = "/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3"
sys.path.append(str(PRJ_ROOT))
from orbit.audio.utils import read_wav_wave
from orbit.audio.analysis import estimate_time_delay
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Explorer Board with (adapted) "example_ffva_ua_fixed_delay" Firmware

# %%
RES_DIR = Path(".").parent / "results"/ "test_delayConfigs_fdPipeline_explorer"
RUNS_PER_CASE = 5
test_cases = dict([ (int(case_dir.name.split("_")[-1]),case_dir) for case_dir in RES_DIR.iterdir() if case_dir.is_dir() ])

# %%
#load data into channels array [test_cases * run_per_test_case, channels, samples]
channels = np.empty((0,0,0))
for idx, dealy in enumerate(sorted(test_cases)):
    print(f"Case {idx+1} - Delay: {dealy}")
    case_dir = test_cases[dealy]
    runs = sorted(case_dir.glob("*.wav"))
    for run in runs:
        print(f"  Run {run.name}")
        fs, data = read_wav_wave( run.absolute().as_posix() )
        if channels.size == 0:
            channels = data[:,:, None].T
        else:
            if channels.shape[2] > data.shape[0]:
                channels = channels[:, :, :data.shape[0]]
            elif channels.shape[2] < data.shape[0]:
                data = data[:channels.shape[2], :]
            channels = np.vstack((channels, data[:,:,None].T))
# Out:
# Case 1 - Delay: -100
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-100/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-100/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-100/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-100/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-100/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 2 - Delay: -50
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-50/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-50/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-50/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-50/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-50/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 3 - Delay: -47
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-47/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-47/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-47/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-47/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-47/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 4 - Delay: -46
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-46/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-46/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-46/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-46/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-46/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 5 - Delay: -45
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-45/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-45/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-45/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-45/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-45/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 6 - Delay: -44
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-44/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-44/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-44/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-44/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-44/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 7 - Delay: -20
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-20/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-20/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-20/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-20/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-20/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
# Case 8 - Delay: -15
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-15/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-15/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-15/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-15/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-15/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
# Case 9 - Delay: -10
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-10/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-10/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-10/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-10/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-10/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926497
# Case 10 - Delay: -5
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-5/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-5/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-5/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-5/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-5/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 11 - Delay: -2
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-2/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-2/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-2/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-2/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-2/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 12 - Delay: -1
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-1/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-1/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-1/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-1/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_-1/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
# Case 13 - Delay: 0
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_0/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_0/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_0/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_0/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_0/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 14 - Delay: 1
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_1/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_1/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_1/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_1/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_1/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 15 - Delay: 2
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_2/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_2/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_2/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_2/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_2/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 16 - Delay: 5
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_5/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_5/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_5/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_5/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_5/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 17 - Delay: 10
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_10/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_10/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_10/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_10/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_10/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 18 - Delay: 15
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_15/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_15/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_15/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926497
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_15/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_15/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
# Case 19 - Delay: 20
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_20/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_20/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_20/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_20/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_20/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
# Case 20 - Delay: 50
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_50/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_50/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_50/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_50/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_50/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 925815
# Case 21 - Delay: 100
#   Run test_r0.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_100/test_r0.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r1.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_100/test_r1.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r2.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_100/test_r2.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r3.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_100/test_r3.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156
#   Run test_r4.wav
#
#
# Reading '/Users/mischa/Projects/FutureProofHomes/Satellite1-XMOS-15.3/batch_runs/aec/results/test_delayConfigs_fdPipeline_explorer/test_delayConfigs_fdPipeline_explorer_delayCfg_100/test_r4.wav'...
# Channels: 6, Sample Width: 2 bytes, Sample Rate: 16000 Hz, Frames: 926156

# %% [markdown]
# #### Raw Microphone Channels (4 & 5)

# %%
mic_channel_mean_var = channels[:,[4,5],:].var(axis=2).mean(axis=1).reshape(len(test_cases), RUNS_PER_CASE)
channel4 = channels[:,4,:].reshape(len(test_cases), RUNS_PER_CASE, -1)
channel4_var = channel4.var(axis=2)
channel4_var /= mic_channel_mean_var
channel5 = channels[:,5,:].reshape(len(test_cases), RUNS_PER_CASE, -1)
channel5_var = channel5.var(axis=2)
channel5_var /= mic_channel_mean_var

# %%
plt.boxplot( [channel4_var.flatten(), channel5_var.flatten()] );
plt.xticks([1,2], ["Raw-Mic 1 (ch 4)", "Raw-Mic 2 (ch 5)"]);
plt.axhline(1, color='black', linestyle='--');
plt.text(2.02, 1.015, "$(\sigma^2_{mic_1} + \sigma^2_{mic_2})\; / \; 2$", fontsize=10, color='black');
plt.title("Energie Distribution of Raw-Mic Signals \n (Normalized by Mean Energie of Mic Signals per Run)");
plt.ylabel("Normalized Energy");
plt.grid(True);

# %% [markdown]
# - Recordings of Mic1 are consistently about 60% higher than Mic2

# %%
np.mean((channel4_var - channel5_var)/ channel5_var)
# Out:
# 0.6363645302697837

# %% [markdown]
# ### Processed Channel 1 (w/o Auto-Gain-Control)

# %%
#calc variances per run and normalize by mean variance of mic channels
channel1 = channels[:,1,:].reshape(len(test_cases), 5, -1)
channel1_var = channel1.var(axis=2)
channel1_var /= mic_channel_mean_var

# %%
#normalize each run by the mean over the test case
channel1_var_mean = channel1_var.mean(axis=1)
channel1_var_run_norm = channel1_var / channel1_var_mean[:,None]

# %%
plt.title("Distribution of Processed Signal Energies (w/o AGC)\n (Normalized by Mean Energie of Mic Signals and over Test Case Runs)");
plt.boxplot( channel1_var_run_norm );
plt.xticks(range(1, RUNS_PER_CASE+1), [f"Run {i+1}" for i in range(RUNS_PER_CASE)]);
plt.xlabel("Runs per Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");

# %% [markdown]
# - the first run of a test case (after flashing, and hence resetting of the XMOS) has consistently a higher energy than later runs
# - => algorithm needs time (samples) to estimate the parameter of the transfer channel model

# %%
plt.figure(figsize=(10,5))
plt.title("Processed Signal Energies (w/o AGC)\n (Normalized by Mean Energie of Mic Signals)")
plt.plot(channel1_var);
plt.grid(True)
plt.xticks( np.arange(len(test_cases)), map(str, sorted(test_cases.keys())) );
plt.legend([f"Run {i+1}" for i in range(RUNS_PER_CASE)]);
plt.xlabel("Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");

# %%
# Take only Runs 2-5 for each test case
plt.figure(figsize=(10,5))
plt.title("Distribution of Energy of Runs 2-5 per Test Case (w/o AGC)\n (Normalized by Mean Energie of Mic Signals)");
plt.boxplot(channel1_var[:,1:].T);
plt.grid(True)
plt.xticks( np.arange(1, len(test_cases)+1), map(str, sorted(test_cases.keys())) );
plt.xlabel("Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");
plt.ylim(0.006,0.02)
# Out:
# (0.006, 0.02)

# %% [markdown]
# ### Processed Channel 0 (with Auto-Gain-Control)

# %%
#calc variances per run and normalize by mean variance of mic channels
channel0 = channels[:,0,:].reshape(len(test_cases), RUNS_PER_CASE, -1)
channel0_var = channel0.var(axis=2)
channel0_var /= mic_channel_mean_var

# %%
#normalize each run by the mean over the test case
channel0_var_mean = channel0_var.mean(axis=1)
channel0_var_run_norm = channel0_var / channel0_var_mean[:,None]

# %%
plt.title("Distribution of Processed Signal Energies (w. AGC)\n (Normalized by Mean Energie of Mic Signals and over Test Case Runs)");
plt.boxplot( channel0_var_run_norm );
plt.xticks(range(1, RUNS_PER_CASE+1), [f"Run {i+1}" for i in range(RUNS_PER_CASE)]);
plt.xlabel("Runs per Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");

# %%
plt.figure(figsize=(10,5))
plt.title("Processed Signal Energies (w. AGC)\n (Normalized by Mean Energie of Mic Signals)")
plt.plot(channel0_var);
plt.grid(True)
plt.xticks( np.arange(len(test_cases)), map(str, sorted(test_cases.keys())) );
plt.legend([f"Run {i+1}" for i in range(RUNS_PER_CASE)]);
plt.xlabel("Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");

# %%
# Take only Runs 2-5 for each test case
plt.figure(figsize=(10,5))
plt.title("Distribution of Energy of Runs 2-5 per Test Case (w. AGC)\n (Normalized by Mean Energie of Mic Signals)");
plt.boxplot(channel0_var[:,1:].T);
plt.grid(True)
plt.xticks( np.arange(1, len(test_cases)+1), map(str, sorted(test_cases.keys())) );
plt.xlabel("Test Case (configured fixed delay)");
plt.ylabel("Normalized Energy");
plt.ylim(500,5000)
# Out:
# (500.0, 5000.0)

# %% [markdown]
# ### Calculated Delay between Raw Mics and Reference Signals by Maximizing the Cross-Correlation
# ##### Example for Run 2 of Test-Case 0

# %%
audio_data = channels[1,:,:].T
fs=16000
channel_names = [
    "PROC 0",
    "RPOC 1",
    "REF 0",
    "REF 1",
    "MIC 0",
    "MIC 1"
]
combinations = ((2,3),(4,5),(2,4),(2,5),(3,4),(3,5))
fig, axes = plt.subplots(3, 2, figsize=(12, 12), sharex=True)
axes = axes.flatten()
for i, comb in enumerate(combinations):
    chirp_signal = audio_data[:,comb[0]] / np.max(audio_data[:,comb[0]])
    mic_signal = audio_data[:,comb[1]] / np.max(audio_data[:,comb[1]])
    # Estimate the delay
    estimated_delay_sec, correlation = estimate_time_delay(chirp_signal, mic_signal, fs)
    # Plot the cross-correlation
    lags = np.arange(-len(chirp_signal)+ 1, len(chirp_signal)) / fs

    axes[i].plot(lags * 1000, correlation)
    axes[i].axvline(x=estimated_delay_sec * 1000, color='r', linestyle='--', label=f"Estimated Delay: {estimated_delay_sec * 1000:.2f} ms")
    axes[i].set_title(f"CC({channel_names[comb[0]]},{channel_names[comb[1]]}) {estimated_delay_sec * 1000:.2f} ms")
    axes[i].set_xlabel("Time Lag (ms)")
    axes[i].set_ylabel("Correlation")
    axes[i].set_xlim((-80,80))

# %% [markdown]
# ##### Does the measured delay depend on the configured fixed-delay?
#
# Answer: No

# %%
normed = channels / np.max(channels,axis=2)[:,:,None]
est_delays = []
for idx in range(channels.shape[0]):
    this_delays = []
    this_delays.append(estimate_time_delay(normed[idx,2,:], normed[idx,4,:], 16000)[0])
    this_delays.append(estimate_time_delay(normed[idx,2,:], normed[idx,4,:], 16000)[0])
    this_delays.append(estimate_time_delay(normed[idx,3,:], normed[idx,4,:], 16000)[0])
    this_delays.append(estimate_time_delay(normed[idx,3,:], normed[idx,5,:], 16000)[0])
    #this_delays.append(estimate_time_delay(normed[idx,4,:], normed[idx,5,:], 16000)[0])
    est_delays.append(this_delays)
    print(f"Estimated delay for case {idx} is {est_delays[idx]}")
# Out:
# Estimated delay for case 0 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 1 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 2 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 3 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 4 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 5 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 6 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 7 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 8 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 9 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 10 is [0.0468125, 0.0468125, 0.0468125, 0.046875]
# Estimated delay for case 11 is [0.0468125, 0.0468125, 0.0468125, 0.0469375]
# Estimated delay for case 12 is [0.0468125, 0.0468125, 0.0468125, 0.0469375]
# Estimated delay for case 13 is [0.0468125, 0.0468125, 0.0468125, 0.0469375]
# Estimated delay for case 14 is [0.0468125, 0.0468125, 0.0468125, 0.0469375]
# Estimated delay for case 15 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 16 is [0.0464375, 0.0464375, 0.0464375, 0.0465625]
# Estimated delay for case 17 is [0.0464375, 0.0464375, 0.0464375, 0.0465625]
# Estimated delay for case 18 is [0.0464375, 0.0464375, 0.0464375, 0.0465625]
# Estimated delay for case 19 is [0.0464375, 0.0464375, 0.0464375, 0.0465625]
# Estimated delay for case 20 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 21 is [0.046625, 0.046625, 0.046625, 0.04675]
# Estimated delay for case 22 is [0.046625, 0.046625, 0.046625, 0.04675]
# Estimated delay for case 23 is [0.046625, 0.046625, 0.046625, 0.04675]
# Estimated delay for case 24 is [0.046625, 0.046625, 0.046625, 0.04675]
# Estimated delay for case 25 is [0.0463125, 0.0463125, 0.0463125, 0.046375]
# Estimated delay for case 26 is [0.0463125, 0.0463125, 0.0463125, 0.0464375]
# Estimated delay for case 27 is [0.0463125, 0.0463125, 0.0463125, 0.0464375]
# Estimated delay for case 28 is [0.0463125, 0.0463125, 0.0463125, 0.0464375]
# Estimated delay for case 29 is [0.0463125, 0.0463125, 0.0463125, 0.0464375]
# Estimated delay for case 30 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 31 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 32 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 33 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 34 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 35 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 36 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 37 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 38 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 39 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 40 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 41 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 42 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 43 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 44 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 45 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 46 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 47 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 48 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 49 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 50 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 51 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 52 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 53 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 54 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 55 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 56 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 57 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 58 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 59 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 60 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 61 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 62 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 63 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 64 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 65 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 66 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 67 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 68 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 69 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 70 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 71 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 72 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 73 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 74 is [0.046625, 0.046625, 0.046625, 0.0466875]
# Estimated delay for case 75 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 76 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 77 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 78 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 79 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 80 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 81 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 82 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 83 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 84 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 85 is [0.0464375, 0.0464375, 0.0464375, 0.0465]
# Estimated delay for case 86 is [0.0465, 0.0465, 0.0465, 0.0465625]
# Estimated delay for case 87 is [0.04675, 0.04675, 0.04675, 0.0468125]
# Estimated delay for case 88 is [0.04675, 0.04675, 0.04675, 0.0468125]
# Estimated delay for case 89 is [0.04675, 0.04675, 0.04675, 0.0468125]
# Estimated delay for case 90 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 91 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 92 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 93 is [0.0465625, 0.0465625, 0.0465625, 0.0466875]
# Estimated delay for case 94 is [0.0465625, 0.0465625, 0.0465625, 0.046625]
# Estimated delay for case 95 is [0.0466875, 0.0466875, 0.0466875, 0.04675]
# Estimated delay for case 96 is [0.0469375, 0.0469375, 0.0469375, 0.047]
# Estimated delay for case 97 is [0.0469375, 0.0469375, 0.0469375, 0.047]
# Estimated delay for case 98 is [0.0469375, 0.0469375, 0.0469375, 0.047]
# Estimated delay for case 99 is [0.0469375, 0.0469375, 0.0469375, 0.047]
# Estimated delay for case 100 is [0.046625, 0.046625, 0.046625, 0.04675]
# Estimated delay for case 101 is [0.0468125, 0.0468125, 0.0468125, 0.046875]
# Estimated delay for case 102 is [0.0468125, 0.0468125, 0.0468125, 0.046875]
# Estimated delay for case 103 is [0.046875, 0.046875, 0.046875, 0.0469375]
# Estimated delay for case 104 is [0.046875, 0.046875, 0.046875, 0.0469375]

# %%
plt.title("Variation of Estimated Delays over all Test Cases and Runs")
plt.boxplot(np.array(est_delays)*1000);
plt.ylabel("Estimated Delay (ms)");
plt.xticks(range(1,5), ["(REF0, MIC0)", "(REF0, MIC1)", "(REF1, MIC0)", "(REF1, MIC1)"]);
plt.ylim(46.2,47.1)
# Out:
# (46.2, 47.1)
